# %%
import pandas as pd

# Load the profiles file – this contains the country info
profiles = pd.read_csv("wosis_202312_profiles.tsv", sep="\t")

# Check available column names to see what's useful
print(profiles.columns)

# Now filter for Angola
angola_profiles = profiles[profiles['country_name'] == 'Angola']

# Display the number of profiles and a few rows
print(f"Number of soil profiles in Angola: {len(angola_profiles)}")
angola_profiles.head()
